# %%
from google.colab import drive

drive._mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
data=pd.read_csv("/content/drive/MyDrive/DATA SCIENCE/data.csv")
data.head()
# Out:
#           Income  Age  Dependents     Occupation City_Tier          Rent  \
# 0   44637.249636   49           0  Self_Employed    Tier_1  13391.174891
# 1   26858.596592   34           2        Retired    Tier_2   5371.719318
# 2   50367.605084   35           1        Student    Tier_3   7555.140763
# 3  101455.600247   21           0  Self_Employed    Tier_3  15218.340037
# 4   24875.283548   52           4   Professional    Tier_2   4975.056710
#
#    Loan_Repayment    Insurance     Groceries    Transport  ...  \
# 0        0.000000  2206.490129   6658.768341  2636.970696  ...
# 1        0.000000   869.522617   2818.444460  1543.018778  ...
# 2     4612.103386  2201.800050   6313.222081  3221.396403  ...
# 3     6809.441427  4889.418087  14690.149363  7106.130005  ...
# 4     3112.609398   635.907170   3034.329665  1276.155163  ...
#
#    Desired_Savings  Disposable_Income  Potential_Savings_Groceries  \
# 0      6200.537192       11265.627707                  1685.696222
# ...

# %%
data.tail()
# Out:
#               Income  Age  Dependents     Occupation City_Tier          Rent  \
# 19995   40913.466178   51           4  Self_Employed    Tier_1  12274.039853
# 19996   90295.772638   21           1        Student    Tier_2  18059.154528
# 19997   40604.567373   30           1   Professional    Tier_2   8120.913475
# 19998  118157.817240   27           2   Professional    Tier_1  35447.345172
# 19999    8209.249769   62           3   Professional    Tier_1   2462.774931
#
#        Loan_Repayment    Insurance     Groceries    Transport  ...  \
# 19995     7703.854895  1646.799940   5477.403246  2084.230191  ...
# 19996        0.000000  2770.589626  13118.222419  4633.108332  ...
# 19997     8089.612716  1548.564328   6018.276121  2493.563674  ...
# 19998    12345.910538  4735.672471  16392.438426  8248.242279  ...
# 19999     1120.881704   276.376556    969.916908   460.435438  ...
#
#        Desired_Savings  Disposable_Income  Potential_Savings_Groceries  \
# ...

# %%
data.describe()
# Out:
#              Income           Age    Dependents           Rent  \
# count  2.000000e+04  20000.000000  20000.000000   20000.000000
# mean   4.158550e+04     41.031450      1.995950    9115.494629
# std    4.001454e+04     13.578725      1.417616    9254.228188
# min    1.301187e+03     18.000000      0.000000     235.365692
# 25%    1.760488e+04     29.000000      1.000000    3649.422246
# 50%    3.018538e+04     41.000000      2.000000    6402.751824
# 75%    5.176545e+04     53.000000      3.000000   11263.940492
# max    1.079728e+06     64.000000      4.000000  215945.674703
#
#        Loan_Repayment     Insurance      Groceries     Transport  \
# count    20000.000000  20000.000000   20000.000000  20000.000000
# mean      2049.800292   1455.028761    5205.667493   2704.466685
# std       4281.789941   1492.938435    5035.953689   2666.345648
# min          0.000000     30.002012     154.078240     81.228584
# 25%          0.000000    580.204749    2165.426419   1124.578012
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Income                           20000 non-null  float64
#  1   Age                              20000 non-null  int64
#  2   Dependents                       20000 non-null  int64
#  3   Occupation                       20000 non-null  object
#  4   City_Tier                        20000 non-null  object
#  5   Rent                             20000 non-null  float64
#  6   Loan_Repayment                   20000 non-null  float64
#  7   Insurance                        20000 non-null  float64
#  8   Groceries                        20000 non-null  float64
#  9   Transport                        20000 non-null  float64
#  10  Eating_Out                       20000 non-null  float64
# ...

# %%
data.shape
# Out:
# (20000, 27)

# %%
data.size
# Out:
# 540000

# %%
data.columns
# Out:
# Index(['Income', 'Age', 'Dependents', 'Occupation', 'City_Tier', 'Rent',
#        'Loan_Repayment', 'Insurance', 'Groceries', 'Transport', 'Eating_Out',
#        'Entertainment', 'Utilities', 'Healthcare', 'Education',
#        'Miscellaneous', 'Desired_Savings_Percentage', 'Desired_Savings',
#        'Disposable_Income', 'Potential_Savings_Groceries',
#        'Potential_Savings_Transport', 'Potential_Savings_Eating_Out',
#        'Potential_Savings_Entertainment', 'Potential_Savings_Utilities',
#        'Potential_Savings_Healthcare', 'Potential_Savings_Education',
#        'Potential_Savings_Miscellaneous'],
#       dtype='object')

# %%
for i in data.columns:
  print(data[i].unique(),i)
# Out:
# [ 44637.24963569  26858.59659173  50367.60508358 ...  40604.56737268
#  118157.81724      8209.24976874] Income
# [49 34 35 21 52 57 53 40 32 30 31 54 22 39 45 62 55 46 37 19 47 59 56 63
#  27 33 23 58 60 24 51 43 28 42 36 50 20 41 38 61 48 64 44 26 18 29 25] Age
# [0 2 1 4 3] Dependents
# ['Self_Employed' 'Retired' 'Student' 'Professional'] Occupation
# ['Tier_1' 'Tier_2' 'Tier_3'] City_Tier
# [13391.17489071  5371.71931835  7555.14076254 ...  8120.91347454
#  35447.345172    2462.77493062] Rent
# [    0.          4612.10338649  6809.44142675 ...  8089.61271561
#  12345.91053816  1120.88170406] Loan_Repayment
# [2206.49012926  869.52261697 2201.80004995 ... 1548.56432809 4735.67247107
#   276.37655633] Insurance
# [ 6658.76834057  2818.44446021  6313.22208093 ...  6018.2761207
#  16392.43842599   969.91690756] Groceries
# [2636.9706962  1543.01877776 3221.39640345 ... 2493.5636745  8248.24227874
#   460.43543798] Transport
# ...

# %%
data.isnull().sum()
# Out:
# Income                             0
# Age                                0
# Dependents                         0
# Occupation                         0
# City_Tier                          0
# Rent                               0
# Loan_Repayment                     0
# Insurance                          0
# Groceries                          0
# Transport                          0
# Eating_Out                         0
# Entertainment                      0
# Utilities                          0
# Healthcare                         0
# Education                          0
# Miscellaneous                      0
# Desired_Savings_Percentage         0
# Desired_Savings                    0
# Disposable_Income                  0
# Potential_Savings_Groceries        0
# Potential_Savings_Transport        0
# Potential_Savings_Eating_Out       0
# Potential_Savings_Entertainment    0
# Potential_Savings_Utilities        0
# Potential_Savings_Healthcare       0
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define numerical columns relevant to the dataset
numerical_cols = [
    "Income",
    "Rent",
    "Loan_Repayment",
    "Groceries",
    "Transport",
    "Entertainment",
    "Healthcare",
    "Disposable_Income"
]

# Create a boxplot for outlier detection
plt.figure(figsize=(12, 6))
sns.boxplot(data[numerical_cols])  # Horizontal boxplot for better readability
plt.title("Boxplot for Outlier Detection")
plt.xlabel("Values")
plt.ylabel("Features")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(data['Income'])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(data['Rent'])
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Income                           20000 non-null  float64
#  1   Age                              20000 non-null  int64
#  2   Dependents                       20000 non-null  int64
#  3   Occupation                       20000 non-null  object
#  4   City_Tier                        20000 non-null  object
#  5   Rent                             20000 non-null  float64
#  6   Loan_Repayment                   20000 non-null  float64
#  7   Insurance                        20000 non-null  float64
#  8   Groceries                        20000 non-null  float64
#  9   Transport                        20000 non-null  float64
#  10  Eating_Out                       20000 non-null  float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Occupation']=le.fit_transform(data['Occupation'])
data['City_Tier']=le.fit_transform(data['City_Tier'])

data.head()

# %% [markdown]
# # **DATA** **VISUALIZATIONS**

# %%
#Income vs. Monthly Expenses

import seaborn as sns
import matplotlib.pyplot as plt

data["Total_Expenses"] = data[[
    "Rent", "Loan_Repayment", "Groceries", "Transport",
    "Eating_Out", "Entertainment", "Utilities", "Healthcare"
]].sum(axis=1)

plt.figure(figsize=(10, 6))
sns.scatterplot(data, x="Income", y="Total_Expenses", hue="City_Tier", palette="viridis")
plt.title("Income vs Total Monthly Expenses by City Tier")
plt.xlabel("Income")
plt.ylabel("Total Expenses")
plt.show()

# %%
#Boxplot of Income by City Tier

plt.figure(figsize=(10, 6))
sns.boxplot(data, x="City_Tier", y="Income", palette="pastel")
plt.title("Income Distribution by City Tier")
plt.xlabel("City Tier")
plt.ylabel("Income")
plt.show()
# Out:
# <ipython-input-19-ed4ad660cc65>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data, x="City_Tier", y="Income", palette="pastel")

# %%
#Histogram: Income Distribution

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(data["Income"], bins=30, color="skyblue", edgecolor="black")
plt.title("Income Distribution")
plt.xlabel("Income")
plt.ylabel("Frequency")
plt.show()

# %%
#Pie Chart: Expense Distribution

expense_columns = [
    "Rent", "Loan_Repayment", "Groceries", "Transport",
    "Eating_Out", "Entertainment", "Utilities", "Healthcare"
]

total_expenses = data[expense_columns].mean()
plt.figure(figsize=(8, 8))
plt.pie(total_expenses, labels=expense_columns, autopct="%1.1f%%", colors=plt.cm.Paired.colors)
plt.title("Average Expense Distribution")
plt.show()

# %%
#Bar Plot: Average Spending by Category

plt.figure(figsize=(12, 6))
total_expenses.sort_values().plot(kind='bar', color="coral")
plt.title("Average Spending by Expense Category")
plt.xlabel("Expense Category")
plt.ylabel("Average Monthly Spending")
plt.show()

# %%
#creating model

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score
models = [DecisionTreeRegressor(),RandomForestRegressor(n_estimators=100),SVR(),KNeighborsRegressor()]
for model in models:
  model.fit(x_train,y_train)
  y_pred = model.predict(x_test)
  print(model)
  print(r2_score(y_test,y_pred))
  print('*'*100)
  print()
